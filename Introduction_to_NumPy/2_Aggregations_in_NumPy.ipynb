# %% [markdown]
# ## Aggregations: Min, Max, and Everything in Between

# %% [markdown]
# ## **Summing the Value in an array**

# %%
import numpy as np

L = np.random.random(100)
sum(L)
# Out:
# np.float64(45.29925977585944)

# %%
# NumPy's sum function
np.sum(L)
# Out:
# np.float64(45.29925977585944)

# %%
big_array = np.random.rand(1000000)
# %timeit sum(big_array)
# %timeit np.sum(big_array)
# Out:
# 180 ms ± 31 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.87 ms ± 46.4 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Minimum and Maximum

# %%
min(big_array), max(big_array)
# Out:
# (np.float64(6.123846840733194e-08), np.float64(0.999999473939581))

# %%
np.min(big_array), np.max(big_array)
# Out:
# (np.float64(6.123846840733194e-08), np.float64(0.999999473939581))

# %%
# %timeit min(big_array)
# %timeit np.min(big_array)
print(big_array.min(), big_array.max(), big_array.sum())
# Out:
# 130 ms ± 11.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.79 ms ± 138 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 6.123846840733194e-08 0.999999473939581 500057.1601197506

# %% [markdown]
# ### Multidimensional aggregates

# %%
M = np.random.random((3, 4))
print(M)
# Out:
# [[0.60286332 0.77133353 0.6810042  0.97846087]
#  [0.48146125 0.35172624 0.3812779  0.11233521]
#  [0.93963269 0.86899545 0.88206251 0.40998993]]

# %%
M.sum()
# Out:
# np.float64(7.461143099115795)

# %%
M.min(axis=0)
# Out:
# array([0.48146125, 0.35172624, 0.3812779 , 0.11233521])

# %%
M.max(axis=1)
# Out:
# array([0.97846087, 0.48146125, 0.93963269])

# %% [markdown]
# ## **Example: What is the average Height of US Presidents?**

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\Admin\Desktop\github\python-data-science-handbook\data\president_heights.csv")
heights = np.array(data["height(cm)"])
print(heights)
# Out:
# [189 170 189 163 183 171 185 168 173 183 173 173 175 178 183 193 178 173
#  174 183 183 168 170 178 182 180 183 178 182 188 175 179 183 193 182 183
#  177 185 188 188 182 185 191 182]

# %%
print("Mean heights")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # set plot style
plt.hist(heights)
plt.title('Height Distribution of US Presidents')
plt.xlabel('height (cm)')
plt.ylabel('number')
# Out:
# Text(0, 0.5, 'number')

# %% [markdown]
# ## Broadcasting

# %%
import numpy as np
a = np.array([0, 1, 2])
b = np.array([5, 5, 5])
a + b
# Out:
# array([5, 6, 7])

# %%
M = np.ones((3, 3))
M
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
a = np.arange(3)
b = np.arange(3)[:, np.newaxis]
print(a)
print(b)
# Out:
# [0 1 2]
# [[0]
#  [1]
#  [2]]

# %%
# Example 1
M = np.ones((2, 3))
a = np.arange(3)

# %%
# Example 2
a = np.arange(3).reshape((3, 1))
b = np.arange(3)

# %%
a + b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %%
# Example 3
M = np.ones((3, 2))
a = np.arange(3)
