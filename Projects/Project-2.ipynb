# %% [markdown]
# ## Weather Data Analysis & Trend Detection

# %% [markdown]
# ### 1. Data Loading & Structure

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\github\python-data-science-handbook\Projects\data\DailyDelhiClimateTest.csv")
df
# Out:
#            date   meantemp   humidity  wind_speed  meanpressure
# 0    2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1    2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2    2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3    2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4    2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ..          ...        ...        ...         ...           ...
# 109  2017-04-20  34.500000  27.500000    5.562500    998.625000
# 110  2017-04-21  34.250000  39.375000    6.962500    999.875000
# 111  2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 112  2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 113  2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 5 columns]

# %% [markdown]
# <!-- ## Weather Data Analysis & Trend Detection -->

# %%
# Converting Data column into datetime
df["date"] = pd.to_datetime(df["date"])

# %%
df.set_index("date")
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2017-01-01  15.913043  85.869565    2.743478     59.000000
# 2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ...               ...        ...         ...           ...
# 2017-04-20  34.500000  27.500000    5.562500    998.625000
# 2017-04-21  34.250000  39.375000    6.962500    999.875000
# 2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 4 columns]

# %% [markdown]
# ### 2. Data Cleaning

# %%
df.dropna()
# Out:
#           date   meantemp   humidity  wind_speed  meanpressure
# 0   2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1   2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2   2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3   2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4   2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ..         ...        ...        ...         ...           ...
# 109 2017-04-20  34.500000  27.500000    5.562500    998.625000
# 110 2017-04-21  34.250000  39.375000    6.962500    999.875000
# 111 2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 112 2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 113 2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 5 columns]

# %%
df.drop_duplicates()
# Out:
#           date   meantemp   humidity  wind_speed  meanpressure
# 0   2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1   2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2   2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3   2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4   2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ..         ...        ...        ...         ...           ...
# 109 2017-04-20  34.500000  27.500000    5.562500    998.625000
# 110 2017-04-21  34.250000  39.375000    6.962500    999.875000
# 111 2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 112 2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 113 2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 5 columns]

# %%
df.dtypes
# Out:
# date            datetime64[ns]
# meantemp               float64
# humidity               float64
# wind_speed             float64
# meanpressure           float64
# dtype: object

# %% [markdown]
# ### 3. Time Based Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          114 non-null    datetime64[ns]
#  1   meantemp      114 non-null    float64
#  2   humidity      114 non-null    float64
#  3   wind_speed    114 non-null    float64
#  4   meanpressure  114 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 4.6 KB

# %%
df["month"] = df["date"].dt.month 
df
# Out:
#           date   meantemp   humidity  wind_speed  meanpressure  month
# 0   2017-01-01  15.913043  85.869565    2.743478     59.000000      1
# 1   2017-01-02  18.500000  77.222222    2.894444   1018.277778      1
# 2   2017-01-03  17.111111  81.888889    4.016667   1018.333333      1
# 3   2017-01-04  18.700000  70.050000    4.545000   1015.700000      1
# 4   2017-01-05  18.388889  74.944444    3.300000   1014.333333      1
# ..         ...        ...        ...         ...           ...    ...
# 109 2017-04-20  34.500000  27.500000    5.562500    998.625000      4
# 110 2017-04-21  34.250000  39.375000    6.962500    999.875000      4
# 111 2017-04-22  32.900000  40.900000    8.890000   1001.600000      4
# 112 2017-04-23  32.875000  27.500000    9.962500   1002.125000      4
# 113 2017-04-24  32.000000  27.142857   12.157143   1004.142857      4
#
# [114 rows x 6 columns]

# %%
average_month=df.groupby("month").mean()
average_month
# Out:
#                      date   meantemp   humidity  wind_speed  meanpressure  \
# month
# 1     2017-01-16 00:00:00  15.710873  77.188256    7.162982    986.767947
# 2     2017-02-14 12:00:00  18.349981  64.375728    7.566294   1015.574251
# 3     2017-03-16 00:00:00  23.753760  48.009694    8.884385   1010.469641
# 4     2017-04-12 12:00:00  30.753663  30.408185    9.128446   1004.564831
#
#          year
# month
# 1      2017.0
# 2      2017.0
# 3      2017.0
# 4      2017.0

# %%
df["year"] = df["date"].dt.year
df
# Out:
#           date   meantemp   humidity  wind_speed  meanpressure  month  year
# 0   2017-01-01  15.913043  85.869565    2.743478     59.000000      1  2017
# 1   2017-01-02  18.500000  77.222222    2.894444   1018.277778      1  2017
# 2   2017-01-03  17.111111  81.888889    4.016667   1018.333333      1  2017
# 3   2017-01-04  18.700000  70.050000    4.545000   1015.700000      1  2017
# 4   2017-01-05  18.388889  74.944444    3.300000   1014.333333      1  2017
# ..         ...        ...        ...         ...           ...    ...   ...
# 109 2017-04-20  34.500000  27.500000    5.562500    998.625000      4  2017
# 110 2017-04-21  34.250000  39.375000    6.962500    999.875000      4  2017
# 111 2017-04-22  32.900000  40.900000    8.890000   1001.600000      4  2017
# 112 2017-04-23  32.875000  27.500000    9.962500   1002.125000      4  2017
# 113 2017-04-24  32.000000  27.142857   12.157143   1004.142857      4  2017
#
# [114 rows x 7 columns]

# %%
df.groupby("year").mean()
# Out:
#                     date   meantemp   humidity  wind_speed  meanpressure  \
# year
# 2017 2017-02-26 12:00:00  21.713079  56.258362    8.143924    1004.03509
#
#          month
# year
# 2017  2.421053

# %%
import matplotlib.pyplot as plt
average_month.plot(x="date", y="meantemp")

plt.xlabel("date")
plt.ylabel("temperature")
plt.title("Average Monthly Temperature")

plt.show()
